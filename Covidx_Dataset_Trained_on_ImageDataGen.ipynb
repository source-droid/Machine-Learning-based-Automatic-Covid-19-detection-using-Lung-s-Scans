# %% [markdown]
# <a href="https://colab.research.google.com/github/source-droid/Machine-Learning-based-Automatic-Covid-19-detection-using-Lung-s-Scans/blob/main/Covidx_Dataset_Trained_on_ImageDataGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! unzip '/content/gdrive/MyDrive/Lab 210/COVID-Net-master.zip'

# %%
import pandas as pd

textfile = pd.read_csv("/content/COVID-Net-master/labels/test_COVIDx.txt", header = None, delimiter = " ")

# %%
textfile.columns = ["Index", "filename", "label"]

# %%
textfile.filename[4]
# Out:
# 'f6236cb5-cc36-4ec4-895c-d11ce043341d.png'

# %%
import shutil, os

# %%
for i in range(len(textfile)):
  if(textfile.label[i] == 'normal'):
    full_path = os.path.join('/content/COVID-Net-master/data/test',textfile.filename[i])
    shutil.copy(full_path, '/content/Covid and NON Covid/NON COVID')

# %%
print("Normal Images: ")
len(os.listdir('/content/Covid and NON Covid/NON COVID'))
# Out:
# Normal Images:
# 13501

# %%
count = 0
for i in range(len(textfile)):
  if(textfile.label[i] == 'pneumonia'):
    full_path = os.path.join('/content/COVID-Net-master/data/test',textfile.filename[i])
    shutil.copy(full_path, '/content/Covid and NON Covid/NON COVID')
    count +=1

print("Pneumonia Images: ", count)
# Out:
# Pneumonia Images:  100

# %%
count = 0
for i in range(len(textfile)):
  if(textfile.label[i] == 'COVID-19'):
    full_path = os.path.join('/content/COVID-Net-master/data/test',textfile.filename[i])
    try:
      shutil.copy(full_path, '/content/Covid and NON Covid/Covid')
      count +=1
    except:
      pass

print("COVID-19 Images: ", count)
# Out:
# COVID-19 Images:  10

# %%
len(os.listdir('/content/Covid and NON Covid/NON COVID'))
# Out:
# 13601

# %%
! git clone 'https://github.com/source-droid/Covid-19-CXR-Dataset.git'
# Out:
# Cloning into 'Covid-19-CXR-Dataset'...
# remote: Enumerating objects: 4366, done.
# remote: Total 4366 (delta 0), reused 0 (delta 0), pack-reused 4366
# Receiving objects: 100% (4366/4366), 2.82 GiB | 27.31 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Checking out files: 100% (4350/4350), done.

# %%
pth = os.listdir('/content/Covid-19-CXR-Dataset/test/Covid')

# %%
count = 0
for i ,j in enumerate(pth):

  full_path = os.path.join('/content/Covid-19-CXR-Dataset/test/Covid',j)
  shutil.copy(full_path, '/content/Covid and NON Covid/Covid')
  count +=1

print("Covid Images: ", count)

# %%
pth = os.listdir('/content/Covid-19-CXR-Dataset/test/Normal')
count = 0
for i ,j in enumerate(pth):
  full_path = os.path.join('/content/Covid-19-CXR-Dataset/test/Normal',j)
  shutil.copy(full_path, '/content/Covid and NON Covid/NON COVID')
  count +=1

print("Normal Images: ", count)
# Out:
# Normal Images:  269

# %%
pth = os.listdir('/content/Covid-19-CXR-Dataset/test/Viral Pneumonia')
count = 0
for i ,j in enumerate(pth):
  full_path = os.path.join('/content/Covid-19-CXR-Dataset/test/Viral Pneumonia',j)
  shutil.copy(full_path, '/content/Covid and NON Covid/NON COVID')
  count +=1

print("Normal Images: ", count)
# Out:
# Normal Images:  269

# %%
pth = os.listdir('/content/Covid-19-CXR-Dataset/train/Covid')
count = 0
for i ,j in enumerate(pth):
  full_path = os.path.join('/content/Covid-19-CXR-Dataset/train/Covid',j)
  shutil.copy(full_path, '/content/Covid and NON Covid/Covid')
  count +=1

print("Normal Images: ", count)
# Out:
# Normal Images:  1330

# %%
pth = os.listdir('/content/Covid-19-CXR-Dataset/train/Normal')
count = 0
for i ,j in enumerate(pth):
  full_path = os.path.join('/content/Covid-19-CXR-Dataset/train/Normal',j)
  shutil.copy(full_path, '/content/Covid and NON Covid/NON COVID')
  count +=1

print("Normal Images: ", count)
# Out:
# Normal Images:  1072

# %%
pth = os.listdir('/content/Covid-19-CXR-Dataset/train/Viral Pneumonia')
count = 0
for i ,j in enumerate(pth):
  full_path = os.path.join('/content/Covid-19-CXR-Dataset/train/Viral Pneumonia',j)
  shutil.copy(full_path, '/content/Covid and NON Covid/NON COVID')
  count +=1

print("Normal Images: ", count)
# Out:
# Normal Images:  1076

# %% [markdown]
# # Copy Dataset into Google Drive

# %%
# !zip -r file.zip '/content/Covid and non Covid Splitted'
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/Covid and non Covid Splitted/train/NON COVID/296a0445-1221-4911-9bf2-52c67c52dd63.png (deflated 1%)
#   adding: content/Covid and non Covid Splitted/train/NON COVID/8b7729cf-8961-452c-8b03-926516ac5c90.png (deflated 3%)
#   adding: content/Covid and non Covid Splitted/train/NON COVID/0e302d0d-b8c2-4d92-a735-12e843ff89df.png (deflated 1%)
#   adding: content/Covid and non Covid Splitted/train/NON COVID/NORMAL (757).png (deflated 25%)
#   adding: content/Covid and non Covid Splitted/train/NON COVID/Viral Pneumonia (160).png (deflated 23%)
#   adding: content/Covid and non Covid Splitted/train/NON COVID/54cbe63c-5c44-4d55-ae01-0096c805dda1.png (deflated 2%)
#   adding: content/Covid and non Covid Splitted/train/NON COVID/6ce63faf-9387-4c60-991b-11771dc50c98.png (deflated 1%)
#   adding: content/Covid and non Covid Splitted/train/NON COVID/b057c325-eb7b-498f-9aa7-92b599ec36cd.png (deflated 1%)
# ...

# %%
# !cp -r '/content/file.zip' '/content/gdrive/MyDrive/Temp'

# %% [markdown]
# # Train and Test Split

# %%
categories = ['Covid', 'NON COVID']
directory = '/content/Covid and NON Covid'

# %%
# Splitting into Train and Test Covid
import random
import os
filenames1 = os.listdir(os.path.join(directory,categories[0]))

random.shuffle(filenames1)  # randomly shuffles the ordering of filenames

split_1 = int(0.8 * len(filenames1))
#split_2 = int(0.9 * len(filenames))
train_filenames1 = filenames1[:split_1]
# dev_filenames = filenames[split_1:split_2]
test_filenames1 = filenames1[split_1:]

# %%
# Splitting into Train and Test NON-COVID
import random

filenames2 = os.listdir(os.path.join(directory,categories[1]))

random.shuffle(filenames2)  # randomly shuffles the ordering of filenames

split_1 = int(0.8 * len(filenames2))
split_2 = int(0.9 * len(filenames2))
train_filenames2 = filenames2[:split_1]
# dev_filenames = filenames[split_1:split_2]
test_filenames2 = filenames2[split_1:]

# %%
import os
import numpy as np
import shutil

#Creating Train / Test folders (One time use)

root_dir = '/content/Covid and non Covid Splitted'
posCls = '/Covid'
negCls = '/NON COVID'


os.makedirs(root_dir +'/train' + posCls)
os.makedirs(root_dir +'/train' + negCls)
os.makedirs(root_dir +'/test' + posCls)
os.makedirs(root_dir +'/test' + negCls)


# Covid Train and Test
for file_name in train_filenames1:
    shutil.copy(os.path.join(directory,categories[0], file_name), os.path.join(root_dir +'/train' + posCls))
for file_name in test_filenames1:
    shutil.copy(os.path.join(directory,categories[0], file_name), os.path.join(root_dir +'/test' + posCls))
    
# NON Covid Train and test
for file_name in train_filenames2:
    shutil.copy(os.path.join(directory,categories[1], file_name), os.path.join(root_dir +'/train' + negCls))
for file_name in test_filenames2:
    shutil.copy(os.path.join(directory,categories[1], file_name), os.path.join(root_dir +'/test' + negCls))

# %% [markdown]
# # Import Libaries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

from sklearn.metrics import plot_confusion_matrix
import sklearn.metrics as metrics
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

# %%
import os
base_dir = '/content/gdrive/MyDrive/Temp/Covid and non Covid'
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

train_covid_dir = os.path.join(train_dir, 'Covid')
train_normal_dir = os.path.join(train_dir, 'non covid')


test_covid_dir = os.path.join(test_dir, 'Covid')
test_normal_dir = os.path.join(test_dir, 'non covid')

# %%
train_covid_names = os.listdir(train_covid_dir)
print(train_covid_names[:3])

train_normal_names = os.listdir(train_normal_dir)
print(train_normal_names[:3])



test_covid_names = os.listdir(test_covid_dir)
print(test_covid_names[:3])

test_normal_names = os.listdir(test_normal_dir)
print(test_normal_names[:3])
# Out:
# ['4fed5061.jpg', 'COVID-19 (1107).png', 'COVID-19 (844).png']
# ['Viral Pneumonia (1106).png', 'Viral Pneumonia (1308).png', 'Viral Pneumonia (717).png']
# ['COVID-19 (430).png', '16669_3_1.jpeg', '270_2020_2470_Fig1_HTML-b.png']
# ['NORMAL (888).png', 'NORMAL (135).png', 'NORMAL (626).png']

# %%
print("train dataset covid images: ", len(train_covid_names))
print("train dataset normal images: ", len(train_normal_names))

print("test dataset covid images: ", len(test_covid_names))
print("test dataset normal images: ", len(test_normal_names))


print("total train images: ", len(train_covid_names+train_normal_names))
print("total test images: ", len(test_covid_names+test_normal_names))
# Out:
# train dataset covid images:  1330
# train dataset normal images:  2148
# test dataset covid images:  333
# test dataset normal images:  538
# total train images:  3478
# total test images:  871

# %% [markdown]
# # Generating Training, Validation & testing Batches

# %%
# Generator for our training data
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

#Generator for our Validation data
validation_datagen = ImageDataGenerator(rescale = 1./255)

#Generator for our test data
test_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size = (150,150),
                                                    subset = 'training',
                                                    batch_size = 32,
                                                    class_mode = 'binary')

validation_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size = (150,150),
                                                    subset = 'validation',
                                                    batch_size = 32,
                                                    class_mode = 'binary')

test_generator = test_datagen.flow_from_directory(test_dir,
                                                    target_size = (150,150),
                                                    batch_size = 32,
                                                    class_mode = 'binary')
# Out:
# Found 2783 images belonging to 2 classes.
# Found 695 images belonging to 2 classes.
# Found 871 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'Covid': 0, 'non covid': 1}

# %%
train_generator.image_shape
# Out:
# (256, 256, 3)

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(12, 24))
files = 0
for i in range(0, 15):
    
    plt.subplot(5, 3, i+1)
    
    for X_batch in range(1922):
        img = mpimg.imread(train_generator.filepaths[files])
        #image = X_batch[files]
        plt.imshow(img)
        plt.xlabel(train_generator.filenames[files] )
        files = random.randrange(0, 1922, 1)
        break
        
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dataset
#
# ## Credits and Links
#
# 1. [Covid Chest X Ray Dataset](https://github.com/ieee8023/covid-chestxray-dataset)
#
#   520 Covid-19 Images
#
# 2. [COVID-19 Radiography Database](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
#
#   1341 Normal Images<br>
#   1143 Covid-19 Images <br>
#   1345 Viral Pneumonia Images<br>
#
#
# # `Our Dataset`
# Split | Normal | Covid19|Viral Pneumonia|Total|
# ------|:------:|:------:|:---:          |:---:|
# Train | 1072   |1330    |1076           |3478 |
# Test  | 269    |333     | 269           |871  |
# **Total**| **1341**   | **1663**    |   **1345**     |   **4349**   |

# %% [markdown]
# # Build CNN Model

# %%
# Model With Dropout Layer


model = Sequential()

# add the convolutional layer
# filters, size of filters, padding, activation_function, inout_shape
model.add(Conv2D(32,(5,5), padding = 'SAME', activation = 'relu', input_shape = (150,150,3)))

# pooling layer
model.add(MaxPooling2D(pool_size = (2,2)))

# place a dropout layer
model.add(Dropout(0.5)) ## Minimizes the overfitting

# add another convolutional layer
model.add(Conv2D(64,(5,5), padding = 'SAME', activation = 'relu'))

# pooling layer
model.add(MaxPooling2D(pool_size = (2,2)))

# place a dropout layer
model.add(Dropout(0.5))

# Flatten the image to 1 dimensional array
model.add(Flatten())

# add a dense layer : amount of nodes, activation
model.add(Dense(256, activation = 'relu'))

# place a dropout layer
# 0.5 drop out rate is recommended, half input will be dropped at each update
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 87616)             0
# ...

# %%
tf.keras.utils.plot_model(model)

# %%
# Model Without Dropout Layer


model2 = Sequential()

# add the convolutional layer
# filters, size of filters, padding, activation_function, inout_shape
model2.add(Conv2D(32,(5,5), padding = 'SAME', activation = 'relu', input_shape = (150,150,3)))

# pooling layer
model2.add(MaxPooling2D(pool_size = (2,2)))

# place a dropout layer
#model2.add(Dropout(0.5)) ## Minimizes the overfitting

# add another convolutional layer
model2.add(Conv2D(64,(5,5), padding = 'SAME', activation = 'relu'))

# pooling layer
model2.add(MaxPooling2D(pool_size = (2,2)))

# place a dropout layer
#model2.add(Dropout(0.5))

# Flatten the image to 1 dimensional array
model2.add(Flatten())

# add a dense layer : amount of nodes, activation
model2.add(Dense(256, activation = 'relu'))

# place a dropout layer
# 0.5 drop out rate is recommended, half input will be dropped at each update
#model2.add(Dropout(0.5))
model2.add(Dense(1, activation = 'sigmoid'))
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 64)        51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 87616)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               22429952
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# ...

# %%
tf.keras.utils.plot_model(model2)

# %% [markdown]
# # Compile & Train Model

# %%
# compile model
from tensorflow.keras.optimizers import Adam # Adam is optimizer
# Loss function definition
model.compile(Adam(lr = 0.001),loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# compile model
from tensorflow.keras.optimizers import Adam # Adam is optimizer
# Loss function definition
model2.compile(Adam(lr = 0.001),loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# train the model
# %%time
history1 = model.fit(train_generator,
                              epochs=30,
                              validation_data = validation_generator,
                              validation_steps = 10)
# Out:
# Epoch 1/30
# 87/87 [==============================] - 938s 11s/step - loss: 0.9510 - accuracy: 0.7879 - val_loss: 0.2947 - val_accuracy: 0.9531
# Epoch 2/30
# 87/87 [==============================] - 314s 4s/step - loss: 0.2129 - accuracy: 0.9203 - val_loss: 0.1156 - val_accuracy: 0.9688
# Epoch 3/30
# 87/87 [==============================] - 291s 3s/step - loss: 0.1862 - accuracy: 0.9334 - val_loss: 0.1542 - val_accuracy: 0.9656
# Epoch 4/30
# 87/87 [==============================] - 276s 3s/step - loss: 0.1368 - accuracy: 0.9531 - val_loss: 0.1143 - val_accuracy: 0.9688
# Epoch 5/30
# 87/87 [==============================] - 268s 3s/step - loss: 0.1428 - accuracy: 0.9505 - val_loss: 0.1235 - val_accuracy: 0.9656
# Epoch 6/30
# 87/87 [==============================] - 266s 3s/step - loss: 0.1286 - accuracy: 0.9552 - val_loss: 0.0886 - val_accuracy: 0.9656
# Epoch 7/30
# ...

# %%
# train the model
# %%time
history2 = model2.fit(train_generator,
                              epochs=30,
                              validation_data = validation_generator,
                              validation_steps = 10)
# Out:
# Epoch 1/30
# 87/87 [==============================] - 261s 3s/step - loss: 0.9061 - accuracy: 0.7564 - val_loss: 0.1714 - val_accuracy: 0.9438
# Epoch 2/30
# 87/87 [==============================] - 263s 3s/step - loss: 0.1740 - accuracy: 0.9261 - val_loss: 0.1694 - val_accuracy: 0.9406
# Epoch 3/30
# 87/87 [==============================] - 260s 3s/step - loss: 0.1909 - accuracy: 0.9335 - val_loss: 0.1220 - val_accuracy: 0.9688
# Epoch 4/30
# 87/87 [==============================] - 260s 3s/step - loss: 0.1374 - accuracy: 0.9484 - val_loss: 0.0954 - val_accuracy: 0.9656
# Epoch 5/30
# 87/87 [==============================] - 257s 3s/step - loss: 0.0968 - accuracy: 0.9675 - val_loss: 0.0750 - val_accuracy: 0.9781
# Epoch 6/30
# 87/87 [==============================] - 257s 3s/step - loss: 0.1069 - accuracy: 0.9637 - val_loss: 0.1269 - val_accuracy: 0.9594
# Epoch 7/30
# ...

# %%
model_save_name = 'covid+nonCovid_IBA_DATASET_with_dropout.h5'
path = F"/content/gdrive/MyDrive/Temp/{model_save_name}" 
model.save(path)

# %%
model_save_name = 'covid+nonCovid_IBA_DATASET_without_dropout.h5'
path = F"/content/gdrive/MyDrive/Temp/{model_save_name}" 
model2.save(path)

# %%
# plot the model accuracy and loss for the training and the validating set.
# CNN Model
from matplotlib import pyplot as plt
fig, ax = plt.subplots(1, 4, figsize=(30, 5))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'loss', 'accuracy']):
    ax[i].plot(history1.history[met])
    ax[i].plot(history1.history['val_' + met])
    ax[i].set_title('CNN Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
# plot the model accuracy and loss for the training and the validating set.
# CNN Model
from matplotlib import pyplot as plt
fig, ax = plt.subplots(1, 4, figsize=(30, 5))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'loss', 'accuracy']):
    ax[i].plot(history2.history[met])
    ax[i].plot(history2.history['val_' + met])
    ax[i].set_title('CNN Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# # Confusion Matrix

# %%
pred  = model.predict_classes(test_generator,verbose= 1)

'''pred_normalized = []
for i in range(len(pred)):
  if(pred[i]<=0.5):
    pred_normalized.append(1)
  else:
    pred_normalized.append(0)
'''

# %%
import seaborn as sns

cm = confusion_matrix(test_generator.classes, pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Covid', 'Non Covid']); ax.yaxis.set_ticklabels(['Covid', 'Non Covid']);

# %%
pred  = model2.predict_classes(test_generator,verbose= 1)

'''pred_normalized = []
for i in range(len(pred)):
  if(pred[i]<=0.5):
    pred_normalized.append(1)
  else:
    pred_normalized.append(0)
'''
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 28/28 [==============================] - 35s 1s/step
# 'pred_normalized = []\nfor i in range(len(pred)):\n  if(pred[i]<=0.5):\n    pred_normalized.append(1)\n  else:\n    pred_normalized.append(0)\n'

# %%
import seaborn as sns

cm = confusion_matrix(test_generator.classes, pred)
ax= plt.subplot()
sns.heatmap(cm, annot=True, fmt='g', ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Covid', 'Non Covid']); ax.yaxis.set_ticklabels(['Covid', 'Non Covid']);

# %%
from tensorflow import keras
model = keras.models.load_model('/content/gdrive/MyDrive/Temp/covid+nonCovid_IBA_DATASET_with_dropout.h5')

# %%
# ROC
from sklearn.metrics import roc_curve
y_pred_keras = model.predict(test_generator).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(test_generator.classes, y_pred_keras)

# AUC
from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()
